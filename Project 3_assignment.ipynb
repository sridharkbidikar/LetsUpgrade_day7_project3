# %%
# YouTube video downloader

# %%
# !pip install pytube
# Out:
# ...
#      |████████████████████████████████| 40kB 3.5MB/s
# ...

# %%
from pytube import YouTube

# %%
YouTube ('https://youtu.be/w17u_vZ9KAw').streams.first(). download ()
# Out:
# '/content/बुरी तरह हारी Team इंडिया 36 पे all out  India vs Australia Test  Day 3 Highlights  RJ Raunak.mp4'
